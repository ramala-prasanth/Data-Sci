# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
# %matplotlib inline

# %%
# 1. Import data and save it in your disk space (1)
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataSci/Absenteeism_at_work.csv",sep=';')
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
# 2. Drop the columns not required for your analysis. (1)
df1 = df.drop(['Reason for absence','Body mass index','Pet','Weight','Height','Social smoker','Social drinker'],axis=1)
df1
# Out:
#      ID  Month of absence  Day of the week  Seasons  Transportation expense  \
# 0    11                 7                3        1                     289
# 1    36                 7                3        1                     118
# 2     3                 7                4        1                     179
# 3     7                 7                5        1                     279
# 4    11                 7                5        1                     289
# ..   ..               ...              ...      ...                     ...
# 735  11                 7                3        1                     289
# 736   1                 7                3        1                     235
# 737   4                 0                3        1                     118
# 738   8                 0                4        2                     231
# 739  35                 0                6        3                     179
#
# ...

# %%
# 3. Do a missing value analysis and perform appropriate steps to correct them (2)
# Filling the missing values with mode
for i in df1.columns:
  df1[i] = df1[i].fillna(df1[i].mode())
df1
# Out:
#      ID  Month of absence  Day of the week  Seasons  Transportation expense  \
# 0    11                 7                3        1                     289
# 1    36                 7                3        1                     118
# 2     3                 7                4        1                     179
# 3     7                 7                5        1                     279
# 4    11                 7                5        1                     289
# ..   ..               ...              ...      ...                     ...
# 735  11                 7                3        1                     289
# 736   1                 7                3        1                     235
# 737   4                 0                3        1                     118
# 738   8                 0                4        2                     231
# 739  35                 0                6        3                     179
#
# ...

# %%
# 4. Perform an outlier analysis for any two columns (2)

plt.boxplot(df1['Transportation expense'])
plt.show()


plt.boxplot(df1['Distance from Residence to Work'])
plt.show()

# %%
print('Rows with outliers in column Transportation expense:')
print(np.where(df1['Transportation expense']>375))
print(' ')
print('no outliers for column Distance from Residence to Work ')
# Out:
# Rows with outliers in column Transportation expense:
# (array([144, 145, 200, 215, 216, 232, 322, 336, 397, 690, 710]),)
#
# no outliers for column Distance from Residence to Work

# %%
# 5. Do a correlation analysis of any two variables. (2)
df1['Distance from Residence to Work'].corr(df1['Transportation expense'])
# Out:
# 0.26218311063190763

# %%
# 6. Describe the data (1).
df1.describe()
# Out:
#                ID  Month of absence  Day of the week     Seasons  \
# count  740.000000        740.000000       740.000000  740.000000
# mean    18.017568          6.324324         3.914865    2.544595
# std     11.021247          3.436287         1.421675    1.111831
# min      1.000000          0.000000         2.000000    1.000000
# 25%      9.000000          3.000000         3.000000    2.000000
# 50%     18.000000          6.000000         4.000000    3.000000
# 75%     28.000000          9.000000         5.000000    4.000000
# max     36.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
# 7. Display the first 3 rows (1).
df1.head(3)
# Out:
#    ID  Month of absence  Day of the week  Seasons  Transportation expense  \
# 0  11                 7                3        1                     289
# 1  36                 7                3        1                     118
# 2   3                 7                4        1                     179
#
#    Distance from Residence to Work  Service time  Age  Work load Average/day   \
# 0                               36            13   33                 239.554
# 1                               13            18   50                 239.554
# 2                               51            18   38                 239.554
#
#    Hit target  Disciplinary failure  Education  Son  Absenteeism time in hours
# 0          97                     0          1    2                          4
# 1          97                     1          1    1                          0
# 2          97                     0          1    0                          2

# %%
# 8. Display the last 4 rows(1)
df1.tail(4)
# Out:
#      ID  Month of absence  Day of the week  Seasons  Transportation expense  \
# 736   1                 7                3        1                     235
# 737   4                 0                3        1                     118
# 738   8                 0                4        2                     231
# 739  35                 0                6        3                     179
#
#      Distance from Residence to Work  Service time  Age  \
# 736                               11            14   37
# 737                               14            13   40
# 738                               35            14   39
# 739                               45            14   53
#
#      Work load Average/day   Hit target  Disciplinary failure  Education  Son  \
# 736                 264.604          93                     0          3    1
# 737                 271.219          95                     0          1    1
# ...

# %%
# Locate the first row corresponding to the last 3 digits of your Roll No (2)
df2=df1.loc[df1['ID']==249]
df2
# Out:
# Empty DataFrame
# Columns: [ID, Month of absence, Day of the week, Seasons, Transportation expense, Distance from Residence to Work, Service time, Age, Work load Average/day , Hit target, Disciplinary failure, Education, Son, Absenteeism time in hours]
# Index: []

# %%
# 10. How many rows of data do you have? (1)
len(df1)
# Out:
# 740

# %%
# 11. Display the first 5 columns of the first row (2)
df1.iloc[0,:5]
# Out:
# ID                         11.0
# Month of absence            7.0
# Day of the week             3.0
# Seasons                     1.0
# Transportation expense    289.0
# Name: 0, dtype: float64

# %%
# 15. Compute the mean and the variance of &quot;transportation expenses” for medical consultations
# # (1).
print('Mean: ', df1['Transportation expense'].mean())
print('Variance: ', df1['Transportation expense'].var())
# Out:
# Mean:  221.32972972972973
# Variance:  4482.600197491131

# %%
# 16. Draw a histogram for age of Social drinkers. Histogram should be step-filled with bin of
# size 20. Find the skew of this distribution, and comment if it is positive or negative (5).
sns.histplot(df['Social drinker'], bins=20)
print('skew:', df['Social drinker'].skew())
print('It is negatively skewed data. Because from the histogram we can say the skewness is towards the negative of x axis')
# Out:
# skew: -0.2733267156901403
# It is negatively skewed data. Because from the histogram we can say the skewness is towards the negative of x axis

# %%
# 14. Evaluate the characteristics of the population distribution with mean and, deviation (a)
# Average age of highschoolers (b) Average age of graduates (c) Average age of
# # postgraduates (2)
print('Higher secondaru education')
df2 = df.loc[df['Education'] == 1]
print('Mean: ', df2['Age'].mean())
print('deviation:',df2['Age'].std())
df2['Age'].mean()

print('Graduate')
df3 = df.loc[df['Education'] == 2]
print('Mean: ', df3['Age'].mean())
print('deviation:',df3['Age'].std())
df2['Age'].mean()

print('Post graduate')
df4 = df.loc[df['Education'] == 3]
print('Mean: ', df4['Age'].mean())
print('deviation:',df4['Age'].std())
df2['Age'].mean()
# Out:
# Higher secondaru education
# Mean:  37.14238952536825
# deviation: 6.639006951133699
# Graduate
# Mean:  34.0
# deviation: 5.501514942874069
# Post graduate
# Mean:  32.29113924050633
# deviation: 3.105627228172035
# 37.14238952536825

# %%
# 12. Count the number of people affected with the diseases of the circulatory system (2)
dfx = df[df['Reason for absence'] == 9]
dfx.groupby('Reason for absence').count()
# Out:
#                     ID  Month of absence  Day of the week  Seasons  \
# Reason for absence
# 9                    4                 4                4        4
#
#                     Transportation expense  Distance from Residence to Work  \
# Reason for absence
# 9                                        4                                4
#
#                     Service time  Age  Work load Average/day   Hit target  \
# Reason for absence
# 9                              4    4                       4           4
#
#                     Disciplinary failure  Education  Son  Social drinker  \
# Reason for absence
# 9                                      4          4    4               4
#
#                     Social smoker  Pet  Weight  Height  Body mass index  \
# Reason for absence
# 9                               4    4       4       4                4
#
#                     Absenteeism time in hours
# Reason for absence
# 9                                           4

# %%
df1 = df[df['Body mass index']>30]
print("overweight",df1)
df2 = df[df['Body mass index']>=25]

df3 = df2[df2['Body mass index'] <=30]
print(df3)
# Out:
# overweight      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 5     3                  23                 7                6        1
# 13    3                  11                 7                4        1
# 14    3                  23                 7                4        1
# ..   ..                 ...               ...              ...      ...
# 714   2                   0                 6                2        3
# 716  36                  19                 6                5        3
# 725   5                  26                 7                4        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...
