# %%
import pandas as pd
df = pd.read_csv("/content/autoscout24-germany-dataset.csv.zip")
df
type(df)
df.to_csv('C:\MyFiles\car_data.csv')

# %%
df.to_csv('/content/autoscout24-germany-dataset.csv.zip')

# %%
d = pd.read_csv("/content/autoscout24-germany-dataset.csv.zip", nrows=5)
d
# Out:
#    Unnamed: 0  mileage        make   model      fuel    gear offerType  price  \
# 0           0   235000         BMW     316    Diesel  Manual      Used   6800
# 1           1    92800  Volkswagen    Golf  Gasoline  Manual      Used   6877
# 2           2   149300        SEAT    Exeo  Gasoline  Manual      Used   6900
# 3           3    96200     Renault  Megane  Gasoline  Manual      Used   6950
# 4           4   156000     Peugeot     308  Gasoline  Manual      Used   6950
#
#       hp  year
# 0  116.0  2011
# 1  122.0  2011
# 2  160.0  2011
# 3  110.0  2011
# 4  156.0  2011

# %%
import os

# %%
# !dir
# Out:
# autoscout24-germany-dataset[2].csv   C:\\MyFiles\\car_data.csv	   sample_data
# autoscout24-germany-dataset.csv.zip  g_Reading_writing_files.html
