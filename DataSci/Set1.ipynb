# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataSci/Cereals.csv")
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   75.000000   77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   28.246753   2.207792   1.029610   0.821039
# std     4.378656   70.410636   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4             Almond_Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN        25      3     1.0  0.75  34.384843

# %%
df1=df.rename(columns={"mfr":"manufacturer"})
df1
# Out:
#                          name manufacturer type  calories  protein  fat  \
# 0                   100%_Bran            N    C        70        4    1
# 1           100%_Natural_Bran            Q    C       120        3    5
# 2                    All-Bran            K    C        70        4    1
# 3   All-Bran_with_Extra_Fiber            K    C        50        4    0
# 4              Almond_Delight            R    C       110        2    2
# ..                        ...          ...  ...       ...      ...  ...
# 72                    Triples            G    C       110        2    1
# 73                       Trix            G    C       110        1    1
# 74                 Wheat_Chex            R    C       100        3    1
# 75                   Wheaties            G    C       100        3    1
# 76        Wheaties_Honey_Gold            G    C       110        2    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# ...

# %%
df1=df[df['calories']>110]
df1
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100%_Natural_Bran   Q    C       120        3    5
# 7                                  Basic_4   G    C       130        3    2
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 12                   Cinnamon_Toast_Crunch   G    C       120        1    3
# 27  Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   P    C       120        3    2
# 28                           Fruitful_Bran   K    C       120        3    0
# 34                      Great_Grains_Pecan   P    C       120        3    3
# 35                        Honey_Graham_Ohs   Q    C       120        1    2
# 39                  Just_Right_Fruit_&_Nut   K    C       140        3    1
# 44        Muesli_Raisins,_Dates,_&_Almonds   R    C       150        4    3
# 45       Muesli_Raisins,_Peaches,_&_Pecans   R    C       150        4    3
# ...

# %%
df.loc[df.potass>50]
df.iloc[0:6]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4             Almond_Delight   R    C       110        2    2     200    1.0
# 5    Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN        25      3     1.0  0.75  34.384843
# ...

# %%
len(df.loc[df.fat>2])
# Out:
# 6

# %%
for i in df.columns:
  df1=df.groupby(i)[i].count()
  print(i,":",len(df1))
# Out:
# name : 77
# mfr : 7
# type : 2
# calories : 11
# protein : 6
# fat : 5
# sodium : 27
# fiber : 13
# carbo : 21
# sugars : 16
# potass : 35
# vitamins : 3
# shelf : 3
# weight : 7
# cups : 12
# rating : 77

# %%
df1=df.loc[df.calories>110]
df2=df.loc[df.calories<=110]
display(df1)
display(df2)
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100%_Natural_Bran   Q    C       120        3    5
# 7                                  Basic_4   G    C       130        3    2
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 12                   Cinnamon_Toast_Crunch   G    C       120        1    3
# 27  Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   P    C       120        3    2
# 28                           Fruitful_Bran   K    C       120        3    0
# 34                      Great_Grains_Pecan   P    C       120        3    3
# 35                        Honey_Graham_Ohs   Q    C       120        1    2
# 39                  Just_Right_Fruit_&_Nut   K    C       140        3    1
# 44        Muesli_Raisins,_Dates,_&_Almonds   R    C       150        4    3
# 45       Muesli_Raisins,_Peaches,_&_Pecans   R    C       150        4    3
# ...

# %%
df.loc[df.protein>2]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100%_Bran   N    C        70        4    1
# 1                        100%_Natural_Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran_with_Extra_Fiber   K    C        50        4    0
# 7                                  Basic_4   G    C       130        3    2
# 9                              Bran_Flakes   P    C        90        3    0
# 11                                Cheerios   G    C       110        6    2
# 13                                Clusters   G    C       110        3    2
# 19                      Cracklin'_Oat_Bran   K    C       110        3    3
# 20                  Cream_of_Wheat_(Quick)   N    H       100        3    0
# 26                     Frosted_Mini-Wheats   K    C       100        3    0
# ...

# %%
df1=df.loc[df.fiber>2].groupby("mfr")
df1.first()
# Out:
#                 name type  calories  protein  fat  sodium  fiber  carbo  \
# mfr
# G    Raisin_Nut_Bran    C       100        3    2     140    2.5   10.5
# K           All-Bran    C        70        4    1     260    9.0    7.0
# N          100%_Bran    C        70        4    1     130   10.0    5.0
# P        Bran_Flakes    C        90        3    0     210    5.0   13.0
# Q     Quaker_Oatmeal    H       100        5    2       0    2.7    NaN
# R          Bran_Chex    C        90        2    1     200    4.0   15.0
#
#      sugars  potass  vitamins  shelf  weight  cups     rating
# mfr
# G       8.0   140.0        25      3     1.0  0.50  39.703400
# K       5.0   320.0        25      3     1.0  0.33  59.425505
# N       6.0   280.0        25      3     1.0  0.33  68.402973
# P       5.0   190.0        25      3     1.0  0.67  53.313813
# Q       NaN   110.0         0      1     1.0  0.67  50.828392
# R       6.0   125.0        25      1     1.0  0.67  49.120253

# %%
df["fat"].median()
# Out:
# 1.0

# %%
df1=df.loc[df.rating>df["rating"].median()]
df1
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100%_Bran   N    C        70        4    1
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran_with_Extra_Fiber   K    C        50        4    0
# 8                                Bran_Chex   R    C        90        2    1
# 9                              Bran_Flakes   P    C        90        3    0
# 11                                Cheerios   G    C       110        6    2
# 15                               Corn_Chex   R    C       110        2    0
# 16                             Corn_Flakes   K    C       100        2    0
# 19                      Cracklin'_Oat_Bran   K    C       110        3    3
# 20                  Cream_of_Wheat_(Quick)   N    H       100        3    0
# 21                                 Crispix   K    C       110        2    0
# ...

# %%
df.boxplot(column="sodium",)

# %%
# df['calories'].hist()
# df['calories'].skew()

sns.distplot(df['calories'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# df['calories'].skew()
df['sugars'].kurtosis()
# Out:
# -1.153358847980711

# %%
df['potass'] = df['potass'].fillna(df['potass'].mean())
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C      70.0      4.0  1.0   130.0   10.0
# 1           100%_Natural_Bran   Q    C     120.0      3.0  5.0    15.0    2.0
# 2                    All-Bran   K    C      70.0      4.0  1.0   260.0    9.0
# 3   All-Bran_with_Extra_Fiber   K    C      50.0      4.0  0.0   140.0   14.0
# 4              Almond_Delight   R    C     110.0      2.0  2.0   200.0    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C     110.0      2.0  1.0   250.0    0.0
# 73                       Trix   G    C     110.0      1.0  1.0   140.0    0.0
# 74                 Wheat_Chex   R    C     100.0      3.0  1.0   230.0    3.0
# 75                   Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
# 76        Wheaties_Honey_Gold   G    C     110.0      2.0  1.0   200.0    1.0
#
# ...

# %%
samp = [5, 2, 2, 1, 2, 8, 6, 7, 5, 3, 2, 6, 4, 9, 7, 6, 4, 7, 6, 8, 7, 0, 6,
       2, 9, 8, 7, 7, 2, 6, 2, 8, 0, 2, 5, 1, 3, 6, 7, 7, 2, 2, 0, 3, 8, 7,
       4, 0, 5, 7, 5, 4, 4, 9, 5, 1, 6, 6, 0, 9, 4, 2, 0, 8, 7, 5, 1, 1, 2,
       8, 3, 8, 9, 0, 0, 6, 8, 7, 2, 6, 7, 9, 7, 8, 8, 3, 3, 7, 8, 2, 2, 4,
       4, 5, 3, 4, 1, 5, 5, 1]
dfx=pd.DataFrame(samp, columns=['X'])
dfx
# Out:
#     X
# 0   5
# 1   2
# 2   2
# 3   1
# 4   2
# .. ..
# 95  4
# 96  1
# 97  5
# 98  5
# 99  1
#
# [100 rows x 1 columns]

# %%
sns.histplot(dfx, stat='probability', bins=10);
